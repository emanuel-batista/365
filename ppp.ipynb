# %% [markdown]
# <a href="https://colab.research.google.com/github/emanuel-batista/365/blob/main/ppp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def jogar():
    opcoes = ['pedra', 'papel', 'tesoura']
    computador = random.choice(opcoes)

    usuario = input('Escolha pedra, papel ou tesoura: ').lower()

    if usuario not in opcoes:
        print('Escolha inválida!')
        return

    print(f'Computador escolheu: {computador}')

    if usuario == computador:
        print('Empate!')
    elif (usuario == 'pedra' and computador == 'tesoura') or \
         (usuario == 'papel' and computador == 'pedra') or \
         (usuario == 'tesoura' and computador == 'papel'):
        print('Você venceu!')
    else:
        print('Você perdeu!')

jogar()
